# %% [markdown]
# # Proyek UAS PMDPM
#
# <div class="alert alert-block alert-danger">
#
# <b>Harap jangan menghapus cell dan komentar yang diberikan!</b> <a class="tocSkip"></a>
#
# Setiap cell markdown dan code akan berisi instruksi pengerjaan Proyek UAS PMDPM
# </div>
#
# Dalam notebook ini kalian akan diminta untuk membuat sebuah proyek Pembelajaran Mesin menggunakan dataset yang sudah disediakan. Proyek akan terdiri dari proses inisialisasi, data loading, data cleansing, feature engineering, modelling, dan evaluasi model. Pada bagian akhir silahkan berikan laporan singkat dari proyek yang sudah dikerjakan

# %% [markdown]
# ### Inisialisasi
#
# Bagian berikut berisi import library yang dibutuhkan

# %%
#isikan import library di sini
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Loading
#
# Bagian berikut berisi proses data loading, tampilkan 20 baris data teratas!

# %%
#loading data yang akan diolah
df_housing_krisna_ivan=pd.read_csv('paris_housing2000.csv')

# %%
df_housing_krisna_ivan.head(20)
# Out:
#     cityCode  cityPartRange  numPrevOwners  made isNewBuilt hasStormProtector  \
# 0      61648              3              4  1995          N                 Y
# 1      33633              9              1  2011          N                 Y
# 2      80623              1              4  2003          Y                 N
# 3       8862              6              2  1990          N                 N
# 4      27008              6              9  1992          Y                 Y
# 5      82480              5              2  2010          Y                 N
# 6      26761              4              3  1990          Y                 N
# 7      62932              6              3  2000          N                 N
# 8      91418              2              2  2020          N                 Y
# 9      29281              7              6  1995          N                 Y
# 10     40384              5              1  2021          N                 Y
# ...

# %% [markdown]
# ### Data Cleansing
#
# Bagian berikut berisi proses pembersihan data (missing values handling)

# %%
#bersihkan dataset menggunakan metode yang sudah dipelajari
df_housing_krisna_ivan = pd.get_dummies(df_housing_krisna_ivan, 
                                        ['isNewBuilt', 'hasStormProtector',
                                        'hasStorageRoom', 'category'])

# %%
df_housing_krisna_ivan.head(100)
# Out:
#     cityCode  cityPartRange  numPrevOwners  made  basement  attic  garage  \
# 0      61648              3              4  1995      3114   1258     264
# 1      33633              9              1  2011      9390   6219     922
# 2      80623              1              4  2003      2239   2795     951
# 3       8862              6              2  1990      6861   5769     442
# 4      27008              6              9  1992      6618   7045     939
# ..       ...            ...            ...   ...       ...    ...     ...
# 95      5253              3              6  1992      5465   3549     110
# 96     77438              1              4  2008      7384    549     715
# 97     88937              7              8  1990       224   6186     350
# 98     60193              8              6  2005      7988   6306     505
# 99     26066              5              9  2006      3768     79     755
#
#     hasGuestRoom     price  isNewBuilt_N  isNewBuilt_Y  hasStormProtector_N  \
# ...

# %% [markdown]
# ### Data Visualization
#
# Dalam proses visualisasi data, silahkan pilih 5 feature yang menurut Anda perlu divisualisasikan agar mendapat insight dari data.

# %%
#visualisasi fitur menggunakan metode yang sudah dipelajari

new_buildt=df_housing_krisna_ivan.isNewBuilt_Y.value_counts(dropna=False)
# print(new_buildt)
plt.title("Tabel Perbandingan rumah baru data")

plt.xlabel("1 itu yes 0 itu no")
plt.ylabel("Jumlah data")
new_buildt.plot(kind='pie',figsize=(4,4),autopct='%1.1f%%')
# Out:
# <AxesSubplot:title={'center':'Tabel Perbandingan rumah baru data'}, xlabel='1 itu yes 0 itu no', ylabel='isNewBuilt_Y'>

# %%
tahunbuat=df_housing_krisna_ivan.made.value_counts(dropna=False)
# print(tahunbuat)
plt.title("Tabel jumlah berdasarkan tahun buatnya")
plt.xlabel("Berdasarkan Tahun")
plt.ylabel("Jumlah data")
tahunbuat.plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Tabel jumlah berdasarkan tahun buatnya'}, xlabel='Berdasarkan Tahun', ylabel='Jumlah data'>

# %%
ukurangarage=df_housing_krisna_ivan.garage.value_counts(dropna=False)
plt.title("Tabel jumlah garage")
plt.xlabel("Berdasarkan ukuran garage")
plt.ylabel("Jumlah data")
ukurangarage.head(10).plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Tabel jumlah garage'}, xlabel='Berdasarkan ukuran garage', ylabel='Jumlah data'>

# %%
guestroom=df_housing_krisna_ivan.hasGuestRoom.value_counts(dropna=False)

# print(guestroom)
plt.title("Tabel jumlah  Jumlah Kamar Tamu")
plt.xlabel("Berdasarkan Jumlah")
plt.ylabel("Jumlah data")
guestroom.plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Tabel jumlah  Jumlah Kamar Tamu'}, xlabel='Berdasarkan Jumlah', ylabel='Jumlah data'>

# %%
plt.title("Tabel Persebaran Harga")
sns.boxplot(data=df_housing_krisna_ivan.head(10),x='price')
# Out:
# <AxesSubplot:title={'center':'Tabel Persebaran Harga'}, xlabel='price'>

# %% [markdown]
# ### Deskripsi Data Visualization
# Berikan keterangan atau deskripsi singkat mengenai informasi yang diperoleh dari visualisasi data tersebut. Buat deskripsinya di cell markdown ini!

# %% [markdown]
# Berdasarkan terdapat 5 Visualasi data set
# sebagai Berikut :
# - Tabel Perbandingan rumah baru data
# - Tabel jumlah berdasarkan tahun buatnya
# - Tabel jumlah garage
# - Tabel Persebaran Harga
# - Tabel jumlah  Jumlah Kamar Tamu

# %% [markdown]
# 1. Tabel Perbandingan Rumah Baru berdasarkan Data dimana menunjukan bahwa yang merupakan Bangunan sebanyak 1432 sedangkan bangunan lama sebanyak 568 jika di presentasikan dalam diagram pie membentuk jumlah rumah baru sebesar 71.6 % sedangkan bangunan lama sebesar 28,4 %

# %%
print(new_buildt)
# Out:
# 1    1432
# 0     568
# Name: isNewBuilt_Y, dtype: int64

# %% [markdown]
# 2. Tabel Tabel jumlah berdasarkan tahun buatnya berdasarkan Data di bawah ini yang berubah top 10 data teratas menunjukan berdasarkan tahun top 10 dari tersebut bangunan di bangun dimulai pada didominasi pada tahun 2010-an ke atas lalu di susul tahun 1990-an dan terahkir tahun 2000-an

# %%
print(tahunbuat.head(10))
# Out:
# 2016    78
# 2018    76
# 2020    74
# 1996    74
# 1994    73
# 2014    69
# 2009    69
# 2019    69
# 2003    68
# 1990    66
# Name: made, dtype: int64

# %% [markdown]
# 3. Tabel Jumlah Garage berdasarkan Data dimana menunjukan bahwa yang merupakan dimana data 10 terbesar jumlah dari semua dari ukuran terbanyak sebesar 470

# %%
print(ukurangarage.head(10))
# Out:
# 470    8
# 786    7
# 442    7
# 950    7
# 205    7
# 740    6
# 976    6
# 900    6
# 690    6
# 923    6
# Name: garage, dtype: int64
# 2.0

# %% [markdown]
# 4. Tabel  jumlah  Jumlah Kamar Tamu berdasarkan Data dimana menunjukan bahwa yang dimana rentang yang memiliki kamar tamu paling 10 dengan jumlah rumah yang memiliki 209 lalu yang kedua tidak memiliki ruang tamu sebanyak 192 dan median di memiliki 4 ruang

# %%
print(guestroom)
print(guestroom.median())
# Out:
# 10    209
# 0     192
# 9     188
# 1     181
# 2     180
# 5     179
# 4     179
# 7     177
# 3     177
# 8     171
# 6     167
# Name: hasGuestRoom, dtype: int64
# 179.0

# %% [markdown]
# 5. Tabel Persebaran Harga berdasarkan Data dimana menunjukan bahwa yang bahwa tersebar diantara untuk data 10 teratas dari $150.000 sampai $190.000 untuk persebaran harga jual rumah

# %% [markdown]
# ### Modelling
#
# Gunakan Pipeline untuk modelling dan grid search cross-validation untuk pemilihan model terbaik. Gunakan Stratified K-fold Cross Validation dengan nilai k=5. Pipeline terdiri atas data scaling, feature selection, dan classifier.
#
# >Step data scaling untuk membandingkan perlunya data scaling atau tidak. Gunakan tiga nilai pada parameter grid yaitu: [None,Scaler1,Scaler2] Scaler yang digunakan antara lain MinMax, Standard, atau Robust.
#
# >Step feature selection untuk membandingkan metode feature selection yang digunakan. Gunakan tiga metode pada parameter grid yaitu: [None,Selector1,Selector2]. Metode yang digunakan harus statistik univariat (antara SelectKBest atau SelectPercentile) dan SelectFromModel (boleh menggunakan tree-based model atau linear model). Kalian juga perlu melakukan setting parameter grid nilai k atau percentile-nya dan setting model untuk SelectFromModel.
#
# >Step classifier untuk membandingkan algoritme classifier. Gunakan 4 algoritme pembelajaran mesin yaitu Random Forest, Gradient Boosting Classifier, Logistic Regression, dan SVM. Eksplorasi pengaturan parameter yang ada pada algoritme yang akan Anda gunakan, tidak terbatas pada 1-2 parameter saja supaya optimal (selain random_state). Silahkan bereksperimen untuk parameter seperti n_estimators, max_depth untuk tree-based classifier; C untuk Logistic Regression; dan C, gamma, serta kernel untuk SVM agar mendapat akurasi terbaik.
#
# >Tampilkan best estimator dan nilai best score dari grid-search cross-validation. Fit best estimator pada train set kemudian ujikan pada test set dengan fungsi score. Format score 3 digit di belakang koma (.3f).

# %%
X = df_housing_krisna_ivan.drop('isNewBuilt_Y' ,axis=1)
y = df_housing_krisna_ivan.isNewBuilt_Y

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
 X, y, test_size=0.25, random_state=42)

# %%
#cell code ini untuk proses modelling
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
estimators = [('data_scaling', StandardScaler()),
              ('feature_selection', SelectKBest(k=5)),
              ('classification', SVC())]
pipe = Pipeline(estimators)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('data_scaling', StandardScaler()),
#                 ('feature_selection', SelectKBest(k=5)),
#                 ('classification', SVC())])

# %%
pipe.score(X_test, y_test)
# Out:
# 0.762

# %%
pipe1 = Pipeline(estimators)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

# %%
param_grid = [
    {'data_scaling' : [MinMaxScaler(),StandardScaler(),'passthrough'],
             'feature_selection':[SelectKBest()],
             'feature_selection__k': range(2,4),
             'classification': [RandomForestClassifier()],
             'classification__random_state': [0, 42],
             'classification__n_estimators': range(10,20)},
    {'data_scaling' : [MinMaxScaler(),StandardScaler(),'passthrough'],
             'feature_selection':[SelectKBest()],
             'feature_selection__k': range(2,4),
             'classification': [GradientBoostingClassifier()],
             'classification__random_state': [0, 42],
             'classification__n_estimators': range(10,20)},
    {'data_scaling' : [MinMaxScaler(),StandardScaler(),'passthrough'],
             'feature_selection':[SelectKBest()],
             'feature_selection__k': range(2,4),
             'classification': [LogisticRegression()],
             'classification__random_state': [0, 42]},
    {'data_scaling' : [MinMaxScaler(),StandardScaler(),'passthrough'],
             'feature_selection':[SelectKBest()],
             'feature_selection__k': range(2,4),
             'classification': [SVC()],
             'classification__kernel': ['poly','rbf'],
             'classification__C': [0.001, 0.01, 0.1, 1, 10],
             'classification__gamma': [0.01, 0.1]},
]

# %%
skfold=StratifiedKFold(n_splits=5)
grid_search = GridSearchCV(SVC(), param_grid, cv=skfold)

# %%
grid_search = GridSearchCV(pipe1, param_grid=param_grid, cv=skfold)

# %%
grid_search.fit(X_train, y_train)
# Out:
# c:\Users\acer1\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# c:\Users\acer1\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# c:\Users\acer1\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# c:\Users\acer1\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# c:\Users\acer1\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# ...

# %%
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.3f}".format(grid_search.best_score_))
print("Test set score: {:.3f}".format(grid_search.score(X_test, y_test)))
print(grid_search.best_estimator_)
# Out:
# Best parameters: {'classification': RandomForestClassifier(n_estimators=10, random_state=0), 'classification__n_estimators': 10, 'classification__random_state': 0, 'data_scaling': MinMaxScaler(), 'feature_selection': SelectKBest(k=2), 'feature_selection__k': 2}
# Best cross-validation score: 1.000
# Test set score: 1.000
# Pipeline(steps=[('data_scaling', MinMaxScaler()),
#                 ('feature_selection', SelectKBest(k=2)),
#                 ('classification',
#                  RandomForestClassifier(n_estimators=10, random_state=0))])

# %% [markdown]
# ### Evaluasi Model
#
# Bagian berikut berisi evaluasi model menggunakan classification report dan skor AUC. Tampilkan classification report dan AUC dari best estimator yang diperoleh!

# %%
grid_search_pred = grid_search.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
print("Confusion matrix:\n", confusion_matrix(y_test, grid_search_pred))
# Out:
# Confusion matrix:
#  [[138   0]
#  [  0 362]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, grid_search_pred, target_names=['Tidak Baru Dibangun', 'Baru Dibangun']))
# Out:
#                      precision    recall  f1-score   support
#
# Tidak Baru Dibangun       1.00      1.00      1.00       138
#       Baru Dibangun       1.00      1.00      1.00       362
#
#            accuracy                           1.00       500
#           macro avg       1.00      1.00      1.00       500
#        weighted avg       1.00      1.00      1.00       500

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, grid_search.best_estimator_.predict_proba(X_test)[:,1])
# Out:
# 1.0

# %%
from sklearn.metrics import roc_curve

# %%
fpr, tpr, thresholds = roc_curve(y_test, grid_search.best_estimator_.predict_proba(X_test)[:,1])

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
close_zero = np.argmin(np.abs(thresholds))

plt.plot(fpr[close_zero], tpr[close_zero], 'o', markersize=10,
label='threshold zero', fillstyle='none', c='k', mew=2)
plt.legend(loc=4)
plt.plot(fpr, tpr, label="ROC Curve")
plt.xlabel("FPR")
plt.ylabel("TPR (recall)")
# Out:
# Text(0, 0.5, 'TPR (recall)')

# %% [markdown]
# ### Laporan Proyek
#
# Silahkan isi bagian di bawah ini dengan laporan singkat mengenai proyek yang sudah Anda buat. Jelaskan secara singkat tentang:
#
# - dataset yang digunakan beserta deskripsi feature dan targetnya
# - proses data cleansing yang dilakukan
# - proses data visualization yang dilakukan
# - proses feature engineering yang dilakukan
# - proses modeling yang dilakukan
# - model terbaik
# - hasil evaluasi model

# %% [markdown]
# *tulis laporan Anda di cell ini*

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Harap jangan menghapus cell dan komentar yang diberikan!</b> <a class="tocSkip"></a>
#
# Jika code kalian terindikasi copy paste, maka nilai UAS = 0
# </div>

# %% [markdown]
# 1.) Dataset yang digunakan data set paris_housing2000 merupakan data tentang perumahan dengan bentuk perumahan data perumahan yang sudah ada feature yang di pakai standart scaler lalu target yang di tuju adalah X isNewBuillt

# %% [markdown]
# 2.) Proses data cleansing yang dilakukan dari dataset tersedia tidak memiliki data kosong tetapi harus melakukan enskripsi untuk berapa kolom yaitu isNewBuilt, HasStromProtector, hasStrogeRoom dan Cateroty yang dimana data tersebut memiliki 2 value jadi terbentuk 8 kolom baru dengan value masing-masing dengan 1 dan 0

# %% [markdown]
# 3.) Proses data visualization yang dilakukan adalah membuat Tabel sebagai berikut
# - Tabel Perbandingan rumah baru data
# - Tabel Jumlah Berdasarkan Tahun Buatnya
# - Tabel Jumlah Garage
# - Tabel Persebaran Harga
# - Tabel jumlah  Jumlah Kamar Tamu

# %% [markdown]
# 4.) Proses Feature Engineering yang dilakukan
#     adalah melakukan Encoding pada table isNewBuilt, hasStormProtector, hasStorageRoom, dan category

# %% [markdown]
# 5.) Proses Modeling yang dilakukan adalah RandomForestClassifier, GradientBoostingClassifier, LogisticRegression, dan SVC

# %% [markdown]
# 6.) Model Terbaik adalah RandomForestClassifier

# %% [markdown]
# 7.) Hasil Evaluasi Model adalah classification report dengan percision
